# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivaniYadav354/AIML-projects-/blob/main/HR_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HR_Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439208 entries, 0 to 439207
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          439208 non-null  int64
#  1   Employee_ID         439208 non-null  object
#  2   Full_Name           439208 non-null  object
#  3   Department          439208 non-null  object
#  4   Job_Title           439208 non-null  object
#  5   Hire_Date           439208 non-null  object
#  6   Location            439208 non-null  object
#  7   Performance_Rating  439208 non-null  int64
#  8   Experience_Years    439208 non-null  int64
#  9   Status              439208 non-null  object
#  10  Work_Mode           439207 non-null  object
#  11  Salary_INR          439207 non-null  float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 40.2+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Employee_ID', 'Full_Name', 'Department', 'Job_Title',
#        'Hire_Date', 'Location', 'Performance_Rating', 'Experience_Years',
#        'Status', 'Work_Mode', 'Salary_INR'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Employee_ID           0
# Full_Name             0
# Department            0
# Job_Title             0
# Hire_Date             0
# Location              0
# Performance_Rating    0
# Experience_Years      0
# Status                0
# Work_Mode             1
# Salary_INR            1
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Employee_ID            object
# Full_Name              object
# Department             object
# Job_Title              object
# Hire_Date              object
# Location               object
# Performance_Rating      int64
# Experience_Years        int64
# Status                 object
# Work_Mode              object
# Salary_INR            float64
# dtype: object

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df["Department"].unique()
# Out:
# array(['IT', 'Marketing', 'HR', 'Operations', 'Finance', 'Sales', 'R&D'],
#       dtype=object)

# %%
df["Job_Title"].unique()
# Out:
# array(['Software Engineer', 'SEO Specialist', 'HR Manager',
#        'Logistics Coordinator', 'Finance Manager', 'Account Manager',
#        'Financial Analyst', 'Sales Executive', 'Operations Executive',
#        'HR Executive', 'Sales Director', 'DevOps Engineer',
#        'Content Strategist', 'Marketing Executive', 'Research Scientist',
#        'Accountant', 'IT Manager', 'Supply Chain Manager', 'Data Analyst',
#        'Talent Acquisition Specialist', 'Product Developer',
#        'Operations Director', 'CTO', 'Business Development Manager',
#        'Lab Technician', 'CFO', 'Brand Manager', 'HR Director',
#        'Innovation Manager'], dtype=object)

# %%
df["Performance_Rating"].unique()
# Out:
# array([5, 2, 1, 4, 3])

# %%
df["Performance_Rating"].mean().round()
# Out:
# np.float64(3.0)

# %%
import seaborn as sns
sns.countplot(x='Experience_Years', data=df);

# %%
status =df["Status"].value_counts()
status.plot(kind="pie",color="mygr", autopct= "%1.1f%%");

# %%
df["Work_Mode"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Department"].value_counts()
# Out:
# Department
# IT            132024
# Sales          87548
# Operations     66101
# Marketing      53092
# Finance        43612
# HR             34910
# R&D            21921
# Name: count, dtype: int64

# %%
df.groupby("Department")["Salary_INR"].mean().astype(int)
# Out:
# Department
# Finance        941280
# HR             741697
# IT            1130746
# Marketing      770316
# Operations     755215
# R&D            799178
# Sales          793923
# Name: Salary_INR, dtype: int64

# %%
avg_salary = df.groupby("Job_Title")["Salary_INR"].mean().head()

print(avg_salary)
# Out:
# Job_Title
# Account Manager                 7.998801e+05
# Accountant                      6.503676e+05
# Brand Manager                   8.039002e+05
# Business Development Manager    1.252555e+06
# CFO                             7.923825e+05
# Name: Salary_INR, dtype: float64
