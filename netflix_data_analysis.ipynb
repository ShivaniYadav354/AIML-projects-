# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df =pd.read_csv("Netflix Dataset.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# coulmns
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# length of columns
len(df.columns)
# Out:
# 11

# %%
# no. of rows and columns
print("rows:", df.shape[0] )
print("columns:", df.shape[1] )
# Out:
# rows: 7789
# columns: 11

# %%
# top data
df.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# bottom data
df.tail(1)
# Out:
#      Show_Id Category                                    Title  Director Cast  \
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn  NaN
#
#                                     Country   Release_Date Rating Duration  \
# 7788  United Kingdom, Canada, United States  March 1, 2020  TV-MA   90 min
#
#                                  Type  \
# 7788  Documentaries, Music & Musicals
#
#                                             Description
# 7788  This documentary delves into the mystique behi...

# %%
# ramdon data
df.sample(2)
# Out:
#      Show_Id Category                 Title   Director  \
# 7604   s7603  TV Show  White Rabbit Project        NaN
# 2058   s2059  TV Show     Exclusive Edition  James Lee
#
#                                                    Cast        Country  \
# 7604            Tory Belleci, Kari Byron, Grant Imahara  United States
# 2058  Berg Lee, Yise Loo, Alvin Wong, Hady, Monday K...            NaN
#
#           Release_Date Rating  Duration  \
# 7604  December 9, 2016  TV-14  1 Season
# 2058   August 14, 2017  TV-14  1 Season
#
#                                                 Type  \
# 7604  Docuseries, International TV Shows, Reality TV
# 2058               International TV Shows, TV Dramas
#
#                                             Description
# 7604  Kari Byron, Tory Belleci and Grant Imahara ran...
# 2058  Young journalists working for a magazine juggl...

# %%
# for the specific rows data
df.iloc[33:37]
# Out:
#    Show_Id Category         Title               Director  \
# 33     s34    Movie  #realityhigh       Fernando Lebrija
# 34     s35    Movie         #Roxy        Michael Kennedy
# 35     s36    Movie     #Rucker50  Robert McCullough Jr.
# 36     s37    Movie       #Selfie         Cristina Jacob
#
#                                                  Cast        Country  \
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
# 34  Jake Short, Sarah Fisher, Booboo Stewart, Dann...         Canada
# 35                                                NaN  United States
# 36  Flavia Hojda, Crina Semciuc, Olimpia Melinte, ...        Romania
#
#          Release_Date Rating Duration                                    Type  \
# 33  September 8, 2017  TV-14   99 min                                Comedies
# 34     April 10, 2019  TV-14  105 min               Comedies, Romantic Movies
# 35   December 1, 2016  TV-PG   56 min            Documentaries, Sports Movies
# ...

# %%
df.rename(columns={"Show_Id": "ID"}, inplace=True)

# %%
df.rename(columns={"ID":"Show_Id", "Title":"TTL"}, inplace=True)

# %%
df
# Out:
#      Show_Id Category                                      TTL  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.iloc[0]["Show_Id"] = np.nan

# %%
df.iloc[0]["Category"] = np.nan

# %%
df.isnull().sum()
# Out:
# Show_Id            1
# Category           1
# TTL                0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.iloc[1:5]["category"]=np.nan

# %%
df.isnull().sum()
# Out:
# Show_Id            1
# Category           1
# TTL                0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.loc[1:6, "Category"]=np.nan

# %%
d=pd.DataFrame({
    "age" : [np.nan,np.nan,21,32,44],
    "city": ["delhi", "mum", "HR", np.nan, np.nan]
})

# %%
d.isnull().sum()
# Out:
# age     2
# city    2
# dtype: int64

# %%
d["age"].fillna(11)
# Out:
# 0    11.0
# 1    11.0
# 2    21.0
# 3    32.0
# 4    44.0
# Name: age, dtype: float64

# %%
d["city"].fillna("hello")
# Out:
# 0    delhi
# 1      mum
# 2       HR
# 3    hello
# 4    hello
# Name: city, dtype: object

# %% [markdown]
# # filterr for house of cards what is the house id and who isthe director

# %%
df[df["TTL"]=="House of Cards"][["Show_Id", "Director"]]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# #what is the distribution of category columns

# %%
df["Category"].unique()
# Out:
# array([nan, 'Movie', 'TV Show'], dtype=object)

# %%
df["Category"].value_counts()
# Out:
# Category
# Movie      5374
# TV Show    2408
# Name: count, dtype: int64

# %% [markdown]
# #how many movies realsed in year2020

# %%
df[(df["Category"]=="Movie") & (df["Release_Date"].str.contains("2020"))]
# Out:
#      Show_Id Category                                      TTL  \
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# 30       s31    Movie                         #cats_the_mewvie
# 31       s32    Movie                        #FriendButMarried
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# 30               Michael Margolis
# ...

# %% [markdown]
# #in which year highest movies were released?

# %%
df["Release_date"]=pd.to_datetime(df["Release_Date"],format='mixed')

# %%
df["Release_Date"] = pd.to_datetime(df["Release_Date"], errors="coerce")
df["Year"] = df["Release_Date"].dt.year

# %%
df["Year"].value_counts()
# Out:
# Year
# 2019.0    2137
# 2020.0    2009
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64
